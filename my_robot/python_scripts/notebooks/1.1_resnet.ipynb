# %%
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.metrics import accuracy_score,classification_report
from tensorflow.keras.layers import Dense,Flatten,Conv2D,Dropout, BatchNormalization
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.models import Model
from sklearn.metrics import classification_report
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
DATA_DIR = 'data'
IMAGE_DIR = f'../{DATA_DIR}/gestures'

image_generator = ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=False,
    zoom_range=0.1,
    fill_mode='nearest',
    validation_split=0.2
    )

data_train = image_generator.flow_from_directory(
    IMAGE_DIR,
    target_size=(128,128),
    batch_size=256,
    class_mode='categorical',
    shuffle=True,
    subset = 'training'   
)

data_val = image_generator.flow_from_directory(
    IMAGE_DIR,
    target_size=(128,128),
    batch_size=256,
    class_mode='categorical',
    shuffle=True,
    subset = 'validation'   
)

N_CLASSES = data_train.num_classes
# Out:
# Found 4000 images belonging to 5 classes.
# Found 1000 images belonging to 5 classes.

# %%
N_CLASSES = data_train.num_classes
IMSIZE = (128,128,3)

# %%
def finetuned_resnet(include_top=False):
    base_model = ResNet50(include_top=include_top,input_shape=IMSIZE)
    for layer in base_model.layers:
        layer.trainable = False

    x = base_model.output
    x = Flatten()(x)
    x = BatchNormalization()(x)
    x = Dense(1024, activation='relu')(x)
    x = Dropout(0.5)(x)
    if not include_top:
        x = Dense(N_CLASSES, activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=x)
    model.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy'])

    return model

# %%
resnet_model = finetuned_resnet()
# Out:
# 2022-07-09 20:41:37.524897: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-09 20:41:37.528878: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-09 20:41:37.529072: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-09 20:41:37.529572: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-09 20:41:37.530529: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-09 20:41:37.530811: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-09 20:41:37.530938: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-09 20:41:37.933094: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-09 20:41:37.933355: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-09 20:41:37.933496: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-09 20:41:37.933595: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4660 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1660 Ti with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 7.5

# %%
y = data_train.labels

plt.figure("countplot",figsize=(10,6))
sns.countplot(x=y.flatten())
plt.show()

# %%
resnet_model.optimizer.lr = 0.0001
resnet_model.optimizer.momentum = 0.9
with tf.device('/gpu:0'):
    history = resnet_model.fit(data_train, validation_data = data_val, epochs=100)
# Out:
# Epoch 1/100
# 2022-07-09 20:41:43.857506: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8100
# 2022-07-09 20:41:44.274698: W tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 16/16 [==============================] - 24s 1s/step - loss: 0.6828 - accuracy: 0.8213 - val_loss: 2.9284 - val_accuracy: 0.2800
# Epoch 2/100
# 16/16 [==============================] - 14s 862ms/step - loss: 0.2841 - accuracy: 0.9262 - val_loss: 3.0342 - val_accuracy: 0.2150
# Epoch 3/100
# 16/16 [==============================] - 14s 842ms/step - loss: 0.2141 - accuracy: 0.9370 - val_loss: 2.7213 - val_accuracy: 0.2320
# Epoch 4/100
# 16/16 [==============================] - 17s 1s/step - loss: 0.1715 - accuracy: 0.9550 - val_loss: 2.4690 - val_accuracy: 0.3050
# Epoch 5/100
# 16/16 [==============================] - 15s 955ms/step - loss: 0.1464 - accuracy: 0.9560 - val_loss: 2.0820 - val_accuracy: 0.3820
# Epoch 6/100
# 16/16 [==============================] - 15s 910ms/step - loss: 0.1263 - accuracy: 0.9643 - val_loss: 1.6169 - val_accuracy: 0.4550
# Epoch 7/100
# 16/16 [==============================] - 15s 931ms/step - loss: 0.1073 - accuracy: 0.9705 - val_loss: 1.5340 - val_accuracy: 0.4640
# Epoch 8/100
# 16/16 [==============================] - 15s 914ms/step - loss: 0.1042 - accuracy: 0.9693 - val_loss: 1.3695 - val_accuracy: 0.4820
# Epoch 9/100
# 16/16 [==============================] - 15s 904ms/step - loss: 0.0975 - accuracy: 0.9722 - val_loss: 1.0761 - val_accuracy: 0.5390
# Epoch 10/100
# 16/16 [==============================] - 15s 919ms/step - loss: 0.0892 - accuracy: 0.9745 - val_loss: 0.9063 - val_accuracy: 0.6130
# Epoch 11/100
# 16/16 [==============================] - 14s 885ms/step - loss: 0.0863 - accuracy: 0.9755 - val_loss: 0.9481 - val_accuracy: 0.5940
# Epoch 12/100
# 16/16 [==============================] - 15s 906ms/step - loss: 0.0754 - accuracy: 0.9790 - val_loss: 0.6239 - val_accuracy: 0.7780
# Epoch 13/100
# 16/16 [==============================] - 15s 965ms/step - loss: 0.0790 - accuracy: 0.9755 - val_loss: 0.5433 - val_accuracy: 0.8090
# Epoch 14/100
# 16/16 [==============================] - 15s 932ms/step - loss: 0.0652 - accuracy: 0.9833 - val_loss: 0.4813 - val_accuracy: 0.8450
# Epoch 15/100
# 16/16 [==============================] - 14s 889ms/step - loss: 0.0638 - accuracy: 0.9820 - val_loss: 0.4007 - val_accuracy: 0.8630
# Epoch 16/100
# 16/16 [==============================] - 14s 893ms/step - loss: 0.0668 - accuracy: 0.9820 - val_loss: 0.2956 - val_accuracy: 0.9080
# Epoch 17/100
# 16/16 [==============================] - 15s 909ms/step - loss: 0.0571 - accuracy: 0.9835 - val_loss: 0.2878 - val_accuracy: 0.9080
# Epoch 18/100
# 16/16 [==============================] - 15s 906ms/step - loss: 0.0563 - accuracy: 0.9827 - val_loss: 0.2633 - val_accuracy: 0.9160
# Epoch 19/100
# 16/16 [==============================] - 15s 911ms/step - loss: 0.0551 - accuracy: 0.9825 - val_loss: 0.2329 - val_accuracy: 0.9280
# Epoch 20/100
# 16/16 [==============================] - 14s 886ms/step - loss: 0.0473 - accuracy: 0.9855 - val_loss: 0.2047 - val_accuracy: 0.9360
# Epoch 21/100
# 16/16 [==============================] - 15s 937ms/step - loss: 0.0482 - accuracy: 0.9860 - val_loss: 0.2046 - val_accuracy: 0.9340
# Epoch 22/100
# 16/16 [==============================] - 15s 907ms/step - loss: 0.0486 - accuracy: 0.9868 - val_loss: 0.1938 - val_accuracy: 0.9390
# Epoch 23/100
# 16/16 [==============================] - 14s 866ms/step - loss: 0.0461 - accuracy: 0.9875 - val_loss: 0.2013 - val_accuracy: 0.9360
# Epoch 24/100
# 16/16 [==============================] - 14s 862ms/step - loss: 0.0112 - accuracy: 0.9970 - val_loss: 0.1575 - val_accuracy: 0.9540
# Epoch 86/100
# 16/16 [==============================] - 14s 875ms/step - loss: 0.0180 - accuracy: 0.9950 - val_loss: 0.1407 - val_accuracy: 0.9650
# Epoch 87/100
# 16/16 [==============================] - 14s 885ms/step - loss: 0.0147 - accuracy: 0.9962 - val_loss: 0.1280 - val_accuracy: 0.9620
# Epoch 88/100
# 16/16 [==============================] - 15s 940ms/step - loss: 0.0111 - accuracy: 0.9970 - val_loss: 0.1504 - val_accuracy: 0.9580
# Epoch 89/100
# 16/16 [==============================] - 14s 881ms/step - loss: 0.0139 - accuracy: 0.9967 - val_loss: 0.1928 - val_accuracy: 0.9520
# Epoch 90/100
# 16/16 [==============================] - 15s 931ms/step - loss: 0.0163 - accuracy: 0.9958 - val_loss: 0.1369 - val_accuracy: 0.9650
# Epoch 91/100
# 16/16 [==============================] - 15s 904ms/step - loss: 0.0130 - accuracy: 0.9973 - val_loss: 0.1335 - val_accuracy: 0.9660
# Epoch 92/100
# 16/16 [==============================] - 14s 832ms/step - loss: 0.0130 - accuracy: 0.9960 - val_loss: 0.1426 - val_accuracy: 0.9590
# Epoch 93/100
# 16/16 [==============================] - 15s 921ms/step - loss: 0.0148 - accuracy: 0.9973 - val_loss: 0.1327 - val_accuracy: 0.9650
# Epoch 94/100
# 16/16 [==============================] - 15s 911ms/step - loss: 0.0156 - accuracy: 0.9958 - val_loss: 0.1315 - val_accuracy: 0.9690
# Epoch 95/100
# 16/16 [==============================] - 14s 866ms/step - loss: 0.0115 - accuracy: 0.9975 - val_loss: 0.1270 - val_accuracy: 0.9610
# Epoch 96/100
# 16/16 [==============================] - 15s 900ms/step - loss: 0.0158 - accuracy: 0.9950 - val_loss: 0.1165 - val_accuracy: 0.9650
# Epoch 97/100
# 16/16 [==============================] - 15s 933ms/step - loss: 0.0119 - accuracy: 0.9965 - val_loss: 0.1062 - val_accuracy: 0.9700
# Epoch 98/100
# 16/16 [==============================] - 15s 898ms/step - loss: 0.0115 - accuracy: 0.9970 - val_loss: 0.1294 - val_accuracy: 0.9660
# Epoch 99/100
# 16/16 [==============================] - 15s 900ms/step - loss: 0.0134 - accuracy: 0.9952 - val_loss: 0.1098 - val_accuracy: 0.9600
# Epoch 100/100
# 16/16 [==============================] - 16s 971ms/step - loss: 0.0139 - accuracy: 0.9960 - val_loss: 0.1122 - val_accuracy: 0.9660

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.figure("Model Metrics",(20,10))
plt.title('model accuracy')
plt.subplot(2,1,1)
plt.plot(history.history['accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')

plt.subplot(2,1,2)
plt.plot(history.history['val_accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.tight_layout()
plt.show()

# %%
plt.figure("Model Metrics",(20,10))
plt.title('model accuracy')
plt.subplot(2,1,1)
plt.plot(history.history['loss'])
plt.ylabel('loss')
plt.xlabel('epoch')

plt.subplot(2,1,2)
plt.plot(history.history['val_loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.tight_layout()
plt.show()

# %%
resnet_model.save('../model/saved/resnet_model.h5')

# %%
a = open("../movement", 'r', encoding="utf-8").read()
