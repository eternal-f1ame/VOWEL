# %%
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.metrics import accuracy_score,classification_report
from tensorflow.keras.layers import Dense,Flatten,Conv2D,Dropout, BatchNormalization
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.models import Model
from sklearn.metrics import classification_report
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
DATA_DIR = 'data'
IMAGE_DIR = f'../{DATA_DIR}/dataset'

image_generator = ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=False,
    zoom_range=0.1,
    fill_mode='nearest',
    validation_split=0.2
    )

data_train = image_generator.flow_from_directory(
    IMAGE_DIR,
    target_size=(128,128),
    batch_size=256,
    class_mode='categorical',
    shuffle=True,
    subset = 'training'   
)

data_val = image_generator.flow_from_directory(
    IMAGE_DIR,
    target_size=(128,128),
    batch_size=256,
    class_mode='categorical',
    shuffle=True,
    subset = 'validation'   
)

N_CLASSES = data_train.num_classes
# Out:
# Found 4146 images belonging to 5 classes.
# Found 1034 images belonging to 5 classes.

# %%
N_CLASSES = data_train.num_classes
IMSIZE = (128,128,3)

# %%
def finetuned_resnet(include_top=False):
    base_model = ResNet50(include_top=include_top,input_shape=IMSIZE)
    for layer in base_model.layers:
        layer.trainable = False

    x = base_model.output
    x = Flatten()(x)
    x = BatchNormalization()(x)
    x = Dense(1024, activation='relu')(x)
    x = Dropout(0.5)(x)
    if not include_top:
        x = Dense(N_CLASSES, activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=x)
    model.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy'])

    return model

# %%
resnet_model = finetuned_resnet()
# Out:
# 2022-07-09 02:38:55.940540: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-09 02:38:55.945432: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-09 02:38:55.945668: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-09 02:38:55.946186: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-09 02:38:55.946936: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-09 02:38:55.947257: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-09 02:38:55.947485: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-09 02:38:56.444607: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-09 02:38:56.444841: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-09 02:38:56.444994: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-09 02:38:56.445103: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4660 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1660 Ti with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 7.5

# %%
y = data_train.labels

plt.figure("countplot",figsize=(10,6))
sns.countplot(x=y.flatten())
plt.show()

# %%
resnet_model.optimizer.lr = 0.0001
resnet_model.optimizer.momentum = 0.9
with tf.device('/gpu:0'):
    history = resnet_model.fit(data_train, validation_data = data_val, epochs=100)
# Out:
# Epoch 1/100
# 2022-07-09 02:39:03.510024: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8100
# 2022-07-09 02:39:04.036697: W tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 17/17 [==============================] - 26s 1s/step - loss: 1.0498 - accuracy: 0.6512 - val_loss: 2.7875 - val_accuracy: 0.1954
# Epoch 2/100
# 17/17 [==============================] - 16s 950ms/step - loss: 0.6790 - accuracy: 0.7950 - val_loss: 2.8970 - val_accuracy: 0.1954
# Epoch 3/100
# 17/17 [==============================] - 16s 935ms/step - loss: 0.5478 - accuracy: 0.8377 - val_loss: 2.9814 - val_accuracy: 0.1954
# Epoch 4/100
# 17/17 [==============================] - 16s 955ms/step - loss: 0.4823 - accuracy: 0.8524 - val_loss: 3.1196 - val_accuracy: 0.1954
# Epoch 5/100
# 17/17 [==============================] - 16s 951ms/step - loss: 0.4341 - accuracy: 0.8659 - val_loss: 3.2434 - val_accuracy: 0.1954
# Epoch 6/100
# 17/17 [==============================] - 16s 946ms/step - loss: 0.3954 - accuracy: 0.8801 - val_loss: 2.6390 - val_accuracy: 0.1973
# Epoch 7/100
# 17/17 [==============================] - 16s 952ms/step - loss: 0.3490 - accuracy: 0.8999 - val_loss: 3.1629 - val_accuracy: 0.1954
# Epoch 8/100
# 17/17 [==============================] - 16s 952ms/step - loss: 0.3332 - accuracy: 0.9055 - val_loss: 2.7794 - val_accuracy: 0.1954
# Epoch 9/100
# 17/17 [==============================] - 16s 947ms/step - loss: 0.3007 - accuracy: 0.9165 - val_loss: 2.4729 - val_accuracy: 0.2002
# Epoch 10/100
# 17/17 [==============================] - 16s 936ms/step - loss: 0.2836 - accuracy: 0.9194 - val_loss: 2.1215 - val_accuracy: 0.2137
# Epoch 11/100
# 17/17 [==============================] - 16s 949ms/step - loss: 0.2526 - accuracy: 0.9310 - val_loss: 2.1400 - val_accuracy: 0.2389
# Epoch 12/100
# 17/17 [==============================] - 16s 948ms/step - loss: 0.2492 - accuracy: 0.9281 - val_loss: 1.8694 - val_accuracy: 0.2544
# Epoch 13/100
# 17/17 [==============================] - 16s 948ms/step - loss: 0.2429 - accuracy: 0.9317 - val_loss: 1.4875 - val_accuracy: 0.3298
# Epoch 14/100
# 17/17 [==============================] - 16s 949ms/step - loss: 0.2299 - accuracy: 0.9361 - val_loss: 1.2889 - val_accuracy: 0.4168
# Epoch 15/100
# 17/17 [==============================] - 16s 953ms/step - loss: 0.2219 - accuracy: 0.9387 - val_loss: 1.2245 - val_accuracy: 0.4101
# Epoch 16/100
# 17/17 [==============================] - 16s 924ms/step - loss: 0.2075 - accuracy: 0.9428 - val_loss: 1.1902 - val_accuracy: 0.4362
# Epoch 17/100
# 17/17 [==============================] - 16s 903ms/step - loss: 0.2046 - accuracy: 0.9378 - val_loss: 1.0020 - val_accuracy: 0.5155
# Epoch 18/100
# 17/17 [==============================] - 15s 882ms/step - loss: 0.1913 - accuracy: 0.9469 - val_loss: 0.8083 - val_accuracy: 0.6296
# Epoch 19/100
# 17/17 [==============================] - 15s 904ms/step - loss: 0.1840 - accuracy: 0.9472 - val_loss: 0.6995 - val_accuracy: 0.7398
# Epoch 20/100
# 17/17 [==============================] - 16s 912ms/step - loss: 0.1685 - accuracy: 0.9539 - val_loss: 0.6161 - val_accuracy: 0.7718
# Epoch 21/100
# 17/17 [==============================] - 15s 885ms/step - loss: 0.1773 - accuracy: 0.9522 - val_loss: 0.5083 - val_accuracy: 0.8433
# Epoch 22/100
# 17/17 [==============================] - 15s 891ms/step - loss: 0.1583 - accuracy: 0.9590 - val_loss: 0.4459 - val_accuracy: 0.8665
# Epoch 23/100
# 17/17 [==============================] - 15s 893ms/step - loss: 0.1632 - accuracy: 0.9544 - val_loss: 0.4561 - val_accuracy: 0.8540
# Epoch 24/100
# 17/17 [==============================] - 15s 893ms/step - loss: 0.1508 - accuracy: 0.9588 - val_loss: 0.4067 - val_accuracy: 0.8849
# Epoch 25/100
# 17/17 [==============================] - 16s 903ms/step - loss: 0.1546 - accuracy: 0.9559 - val_loss: 0.3685 - val_accuracy: 0.8936
# Epoch 26/100
# 17/17 [==============================] - 15s 892ms/step - loss: 0.1423 - accuracy: 0.9650 - val_loss: 0.3483 - val_accuracy: 0.8946
# Epoch 27/100
# 17/17 [==============================] - 16s 911ms/step - loss: 0.1413 - accuracy: 0.9602 - val_loss: 0.3636 - val_accuracy: 0.8810
# Epoch 28/100
# 17/17 [==============================] - 16s 950ms/step - loss: 0.1417 - accuracy: 0.9573 - val_loss: 0.3337 - val_accuracy: 0.8878
# Epoch 29/100
# 17/17 [==============================] - 16s 953ms/step - loss: 0.1285 - accuracy: 0.9629 - val_loss: 0.3021 - val_accuracy: 0.9043
# Epoch 30/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.1370 - accuracy: 0.9561 - val_loss: 0.3010 - val_accuracy: 0.9014
# Epoch 31/100
# 17/17 [==============================] - 16s 922ms/step - loss: 0.1288 - accuracy: 0.9658 - val_loss: 0.2984 - val_accuracy: 0.8985
# Epoch 32/100
# 17/17 [==============================] - 16s 932ms/step - loss: 0.1242 - accuracy: 0.9679 - val_loss: 0.3148 - val_accuracy: 0.8878
# Epoch 33/100
# 17/17 [==============================] - 16s 929ms/step - loss: 0.1225 - accuracy: 0.9638 - val_loss: 0.3015 - val_accuracy: 0.8917
# Epoch 34/100
# 17/17 [==============================] - 16s 919ms/step - loss: 0.1184 - accuracy: 0.9691 - val_loss: 0.3077 - val_accuracy: 0.8897
# Epoch 35/100
# 17/17 [==============================] - 16s 913ms/step - loss: 0.1122 - accuracy: 0.9677 - val_loss: 0.2955 - val_accuracy: 0.8994
# Epoch 36/100
# 17/17 [==============================] - 16s 925ms/step - loss: 0.1067 - accuracy: 0.9735 - val_loss: 0.2723 - val_accuracy: 0.9023
# Epoch 37/100
# 17/17 [==============================] - 16s 920ms/step - loss: 0.1131 - accuracy: 0.9720 - val_loss: 0.3044 - val_accuracy: 0.8897
# Epoch 38/100
# 17/17 [==============================] - 15s 898ms/step - loss: 0.1049 - accuracy: 0.9720 - val_loss: 0.2792 - val_accuracy: 0.8994
# Epoch 39/100
# 17/17 [==============================] - 16s 914ms/step - loss: 0.1028 - accuracy: 0.9727 - val_loss: 0.2994 - val_accuracy: 0.8936
# Epoch 40/100
# 17/17 [==============================] - 16s 915ms/step - loss: 0.0970 - accuracy: 0.9740 - val_loss: 0.2861 - val_accuracy: 0.8936
# Epoch 41/100
# 17/17 [==============================] - 16s 908ms/step - loss: 0.0989 - accuracy: 0.9761 - val_loss: 0.2934 - val_accuracy: 0.8946
# Epoch 42/100
# 17/17 [==============================] - 16s 910ms/step - loss: 0.0988 - accuracy: 0.9747 - val_loss: 0.3008 - val_accuracy: 0.8907
# Epoch 43/100
# 17/17 [==============================] - 14s 837ms/step - loss: 0.0940 - accuracy: 0.9735 - val_loss: 0.2766 - val_accuracy: 0.8994
# Epoch 44/100
# 17/17 [==============================] - 14s 824ms/step - loss: 0.1009 - accuracy: 0.9718 - val_loss: 0.2774 - val_accuracy: 0.8956
# Epoch 45/100
# 17/17 [==============================] - 15s 846ms/step - loss: 0.0946 - accuracy: 0.9740 - val_loss: 0.2945 - val_accuracy: 0.8859
# Epoch 46/100
# 17/17 [==============================] - 14s 817ms/step - loss: 0.0904 - accuracy: 0.9766 - val_loss: 0.2692 - val_accuracy: 0.8917
# Epoch 47/100
# 17/17 [==============================] - 14s 830ms/step - loss: 0.0886 - accuracy: 0.9749 - val_loss: 0.3097 - val_accuracy: 0.8878
# Epoch 48/100
# 17/17 [==============================] - 14s 818ms/step - loss: 0.0848 - accuracy: 0.9778 - val_loss: 0.3259 - val_accuracy: 0.8762
# Epoch 49/100
# 17/17 [==============================] - 14s 827ms/step - loss: 0.0895 - accuracy: 0.9737 - val_loss: 0.3115 - val_accuracy: 0.8859
# Epoch 50/100
# 17/17 [==============================] - 14s 822ms/step - loss: 0.0889 - accuracy: 0.9785 - val_loss: 0.2889 - val_accuracy: 0.9062
# Epoch 51/100
# 17/17 [==============================] - 14s 831ms/step - loss: 0.0753 - accuracy: 0.9797 - val_loss: 0.3014 - val_accuracy: 0.8926
# Epoch 52/100
# 17/17 [==============================] - 14s 819ms/step - loss: 0.0786 - accuracy: 0.9771 - val_loss: 0.2784 - val_accuracy: 0.9004
# Epoch 53/100
# 17/17 [==============================] - 14s 857ms/step - loss: 0.0894 - accuracy: 0.9759 - val_loss: 0.3002 - val_accuracy: 0.8859
# Epoch 54/100
# 17/17 [==============================] - 14s 825ms/step - loss: 0.0753 - accuracy: 0.9795 - val_loss: 0.2577 - val_accuracy: 0.9033
# Epoch 55/100
# 17/17 [==============================] - 14s 816ms/step - loss: 0.0763 - accuracy: 0.9800 - val_loss: 0.2851 - val_accuracy: 0.8956
# Epoch 56/100
# 17/17 [==============================] - 14s 822ms/step - loss: 0.0645 - accuracy: 0.9846 - val_loss: 0.2377 - val_accuracy: 0.9101
# Epoch 57/100
# 17/17 [==============================] - 14s 816ms/step - loss: 0.0715 - accuracy: 0.9795 - val_loss: 0.3029 - val_accuracy: 0.8859
# Epoch 58/100
# 17/17 [==============================] - 14s 814ms/step - loss: 0.0794 - accuracy: 0.9761 - val_loss: 0.2476 - val_accuracy: 0.9052
# Epoch 59/100
# 17/17 [==============================] - 14s 832ms/step - loss: 0.0743 - accuracy: 0.9800 - val_loss: 0.2517 - val_accuracy: 0.9101
# Epoch 60/100
# 17/17 [==============================] - 14s 806ms/step - loss: 0.0682 - accuracy: 0.9846 - val_loss: 0.2181 - val_accuracy: 0.9217
# Epoch 61/100
# 17/17 [==============================] - 14s 797ms/step - loss: 0.0642 - accuracy: 0.9822 - val_loss: 0.2211 - val_accuracy: 0.9226
# Epoch 62/100
# 17/17 [==============================] - 14s 800ms/step - loss: 0.0703 - accuracy: 0.9819 - val_loss: 0.2582 - val_accuracy: 0.9033
# Epoch 63/100
# 17/17 [==============================] - 14s 794ms/step - loss: 0.0661 - accuracy: 0.9817 - val_loss: 0.2409 - val_accuracy: 0.9101
# Epoch 64/100
# 17/17 [==============================] - 14s 852ms/step - loss: 0.0701 - accuracy: 0.9809 - val_loss: 0.2451 - val_accuracy: 0.9043
# Epoch 65/100
# 17/17 [==============================] - 14s 799ms/step - loss: 0.0605 - accuracy: 0.9850 - val_loss: 0.2510 - val_accuracy: 0.9033
# Epoch 66/100
# 17/17 [==============================] - 14s 793ms/step - loss: 0.0626 - accuracy: 0.9809 - val_loss: 0.2493 - val_accuracy: 0.9043
# Epoch 67/100
# 17/17 [==============================] - 14s 813ms/step - loss: 0.0670 - accuracy: 0.9797 - val_loss: 0.2290 - val_accuracy: 0.9014
# Epoch 68/100
# 17/17 [==============================] - 15s 902ms/step - loss: 0.0678 - accuracy: 0.9831 - val_loss: 0.2458 - val_accuracy: 0.9043
# Epoch 69/100
# 17/17 [==============================] - 15s 939ms/step - loss: 0.0637 - accuracy: 0.9841 - val_loss: 0.2678 - val_accuracy: 0.9043
# Epoch 70/100
# 17/17 [==============================] - 16s 908ms/step - loss: 0.0678 - accuracy: 0.9807 - val_loss: 0.2130 - val_accuracy: 0.9197
# Epoch 71/100
# 17/17 [==============================] - 16s 933ms/step - loss: 0.0582 - accuracy: 0.9841 - val_loss: 0.2546 - val_accuracy: 0.9120
# Epoch 72/100
# 17/17 [==============================] - 16s 918ms/step - loss: 0.0591 - accuracy: 0.9829 - val_loss: 0.2294 - val_accuracy: 0.9139
# Epoch 73/100
# 17/17 [==============================] - 16s 905ms/step - loss: 0.0587 - accuracy: 0.9860 - val_loss: 0.2587 - val_accuracy: 0.8965
# Epoch 74/100
# 17/17 [==============================] - 16s 911ms/step - loss: 0.0517 - accuracy: 0.9850 - val_loss: 0.2246 - val_accuracy: 0.9159
# Epoch 75/100
# 17/17 [==============================] - 16s 918ms/step - loss: 0.0541 - accuracy: 0.9846 - val_loss: 0.2621 - val_accuracy: 0.9081
# Epoch 76/100
# 17/17 [==============================] - 16s 908ms/step - loss: 0.0534 - accuracy: 0.9870 - val_loss: 0.2385 - val_accuracy: 0.9130
# Epoch 77/100
# 17/17 [==============================] - 16s 909ms/step - loss: 0.0533 - accuracy: 0.9870 - val_loss: 0.2960 - val_accuracy: 0.8859
# Epoch 78/100
# 17/17 [==============================] - 16s 922ms/step - loss: 0.0533 - accuracy: 0.9855 - val_loss: 0.2599 - val_accuracy: 0.9004
# Epoch 79/100
# 17/17 [==============================] - 16s 917ms/step - loss: 0.0580 - accuracy: 0.9834 - val_loss: 0.2517 - val_accuracy: 0.9072
# Epoch 80/100
# 17/17 [==============================] - 17s 983ms/step - loss: 0.0609 - accuracy: 0.9822 - val_loss: 0.2289 - val_accuracy: 0.9110
# Epoch 81/100
# 17/17 [==============================] - 16s 963ms/step - loss: 0.0608 - accuracy: 0.9819 - val_loss: 0.2494 - val_accuracy: 0.9043
# Epoch 82/100
# 17/17 [==============================] - 17s 972ms/step - loss: 0.0554 - accuracy: 0.9846 - val_loss: 0.2376 - val_accuracy: 0.9168
# Epoch 83/100
# 17/17 [==============================] - 17s 976ms/step - loss: 0.0539 - accuracy: 0.9848 - val_loss: 0.2222 - val_accuracy: 0.9188
# Epoch 84/100
# 17/17 [==============================] - 17s 977ms/step - loss: 0.0497 - accuracy: 0.9863 - val_loss: 0.2495 - val_accuracy: 0.9101
# Epoch 85/100
# 17/17 [==============================] - 17s 990ms/step - loss: 0.0518 - accuracy: 0.9863 - val_loss: 0.2083 - val_accuracy: 0.9188
# Epoch 86/100
# 17/17 [==============================] - 17s 982ms/step - loss: 0.0470 - accuracy: 0.9884 - val_loss: 0.2263 - val_accuracy: 0.9159
# Epoch 87/100
# 17/17 [==============================] - 17s 1s/step - loss: 0.0469 - accuracy: 0.9870 - val_loss: 0.2363 - val_accuracy: 0.9178
# Epoch 88/100
# 17/17 [==============================] - 17s 1000ms/step - loss: 0.0463 - accuracy: 0.9889 - val_loss: 0.2384 - val_accuracy: 0.9178
# Epoch 89/100
# 17/17 [==============================] - 17s 1s/step - loss: 0.0434 - accuracy: 0.9882 - val_loss: 0.2183 - val_accuracy: 0.9197
# Epoch 90/100
# 17/17 [==============================] - 17s 1s/step - loss: 0.0471 - accuracy: 0.9872 - val_loss: 0.2377 - val_accuracy: 0.9168
# Epoch 91/100
# 17/17 [==============================] - 17s 975ms/step - loss: 0.0471 - accuracy: 0.9875 - val_loss: 0.2498 - val_accuracy: 0.9168
# Epoch 92/100
# 17/17 [==============================] - 17s 987ms/step - loss: 0.0468 - accuracy: 0.9882 - val_loss: 0.2110 - val_accuracy: 0.9188
# Epoch 93/100
# 17/17 [==============================] - 16s 932ms/step - loss: 0.0471 - accuracy: 0.9863 - val_loss: 0.2418 - val_accuracy: 0.9062
# Epoch 94/100
# 17/17 [==============================] - 16s 936ms/step - loss: 0.0458 - accuracy: 0.9867 - val_loss: 0.2390 - val_accuracy: 0.9149
# Epoch 95/100
# 17/17 [==============================] - 17s 1s/step - loss: 0.0530 - accuracy: 0.9853 - val_loss: 0.2487 - val_accuracy: 0.9168
# Epoch 96/100
# 17/17 [==============================] - 17s 1s/step - loss: 0.0489 - accuracy: 0.9875 - val_loss: 0.2221 - val_accuracy: 0.9120
# Epoch 97/100
# 17/17 [==============================] - 17s 977ms/step - loss: 0.0433 - accuracy: 0.9891 - val_loss: 0.2287 - val_accuracy: 0.9139
# Epoch 98/100
# 17/17 [==============================] - 17s 987ms/step - loss: 0.0388 - accuracy: 0.9906 - val_loss: 0.2658 - val_accuracy: 0.9014
# Epoch 99/100
# 17/17 [==============================] - 17s 993ms/step - loss: 0.0478 - accuracy: 0.9865 - val_loss: 0.2330 - val_accuracy: 0.9207
# Epoch 100/100
# 17/17 [==============================] - 17s 1s/step - loss: 0.0397 - accuracy: 0.9901 - val_loss: 0.2214 - val_accuracy: 0.9207

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.figure("Model Metrics",(20,10))
plt.title('model accuracy')
plt.subplot(2,1,1)
plt.plot(history.history['accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')

plt.subplot(2,1,2)
plt.plot(history.history['val_accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.tight_layout()
plt.show()

# %%
plt.figure("Model Metrics",(20,10))
plt.title('model accuracy')
plt.subplot(2,1,1)
plt.plot(history.history['loss'])
plt.ylabel('loss')
plt.xlabel('epoch')

plt.subplot(2,1,2)
plt.plot(history.history['val_loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.tight_layout()
plt.show()

# %%
resnet_model.save('../model/saved/resnet_model.h5')
