# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense,Flatten,Conv2D,Dropout,InputLayer,MaxPool2D
from tensorflow.keras.models import Model,Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy,BinaryCrossentropy,mean_squared_error,mean_absolute_error
from tensorflow.keras.metrics import Accuracy
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
lenc = LabelEncoder()
ohe = OneHotEncoder()

# %%
DATA_DIR = 'data'
IMAGE_DIR = f'../{DATA_DIR}/dataset'

image_generator = ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=False,
    zoom_range=0.1,
    fill_mode='nearest',
    validation_split=0.2
    )

data_train = image_generator.flow_from_directory(
    IMAGE_DIR,
    target_size=(128,128),
    batch_size=256,
    class_mode='categorical',
    shuffle=True,
    subset = 'training'   
)

data_val = image_generator.flow_from_directory(
    IMAGE_DIR,
    target_size=(128,128),
    batch_size=256,
    class_mode='categorical',
    shuffle=True,
    subset = 'validation'   
)

N_CLASSES = data_train.num_classes
# Out:
# Found 4146 images belonging to 5 classes.
# Found 1034 images belonging to 5 classes.

# %%
IMSIZE = (128,128,3)
N_CLASSES = data_train.num_classes

# %%
model = Sequential()
model.add(InputLayer(input_shape=IMSIZE))
model.add(Conv2D(64,(5,5),activation='relu',strides=(2,2),padding='same'))
model.add(Conv2D(64,(3,3),activation='relu',strides=(2,2),padding='same'))

model.add(Conv2D(64,(1,1),activation='relu',padding='same'))
model.add(Conv2D(64,(3,3),activation='relu',padding='same'))
model.add(Conv2D(128,(3,3),activation='relu',padding='same'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(128,(1,1),activation='relu',padding='same'))
model.add(Conv2D(128,(3,3),activation='relu',padding='same'))
model.add(Conv2D(256,(3,3),activation='relu',padding='same'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(256,(1,1),activation='relu',padding='same'))
model.add(Conv2D(256,(3,3),activation='relu',padding='same'))
model.add(Conv2D(512,(3,3),activation='relu',padding='same'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Flatten())

model.add(Dense(1024,activation='relu'))
model.add(Dense(256,activation='relu'))
model.add(Dropout(0.3))

model.add(Dense(N_CLASSES,activation='softmax'))

model.compile(loss='categorical_crossentropy',optimizer='rmsprop',metrics=['accuracy'])
# Out:
# 2022-07-12 05:50:25.721892: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-12 05:50:25.727524: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-12 05:50:25.727758: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-12 05:50:25.728936: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-12 05:50:25.729692: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-12 05:50:25.729972: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-12 05:50:25.730125: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-12 05:50:26.157277: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-12 05:50:26.157468: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-12 05:50:26.157595: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-12 05:50:26.157716: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4660 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1660 Ti with Max-Q Design, pci bus id: 0000:01:00.0, compute capability: 7.5

# %%
y = data_train.labels

plt.figure("countplot",figsize=(10,6))
sns.countplot(x=y.flatten())
plt.show()

# %%
model.optimizer.lr = 0.0001
model.optimizer.momentum = 0.9
with tf.device('/gpu:0'):
    history = model.fit_generator(data_train,epochs=100,validation_data=data_val)
# Out:
# /tmp/ipykernel_132867/1414883363.py:4: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(data_train,epochs=100,validation_data=data_val)
# Epoch 1/100
# 2022-07-12 05:50:30.414642: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8100
# 2022-07-12 05:50:30.856761: W tensorflow/stream_executor/gpu/asm_compiler.cc:111] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 17/17 [==============================] - 25s 1s/step - loss: 1.6085 - accuracy: 0.2113 - val_loss: 1.5982 - val_accuracy: 0.2070
# Epoch 2/100
# 17/17 [==============================] - 17s 987ms/step - loss: 1.5190 - accuracy: 0.3227 - val_loss: 1.4519 - val_accuracy: 0.3037
# Epoch 3/100
# 17/17 [==============================] - 17s 1s/step - loss: 1.4017 - accuracy: 0.3905 - val_loss: 1.3207 - val_accuracy: 0.4642
# Epoch 4/100
# 17/17 [==============================] - 18s 1s/step - loss: 1.2784 - accuracy: 0.4723 - val_loss: 1.1629 - val_accuracy: 0.5348
# Epoch 5/100
# 17/17 [==============================] - 18s 1s/step - loss: 1.1614 - accuracy: 0.5186 - val_loss: 1.0436 - val_accuracy: 0.5909
# Epoch 6/100
# 17/17 [==============================] - 18s 1s/step - loss: 1.0252 - accuracy: 0.5827 - val_loss: 1.0329 - val_accuracy: 0.5561
# Epoch 7/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.9258 - accuracy: 0.6261 - val_loss: 0.7986 - val_accuracy: 0.6847
# Epoch 8/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.8449 - accuracy: 0.6739 - val_loss: 1.0589 - val_accuracy: 0.5851
# Epoch 9/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.7736 - accuracy: 0.7067 - val_loss: 0.6803 - val_accuracy: 0.7563
# Epoch 10/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.6575 - accuracy: 0.7549 - val_loss: 0.7023 - val_accuracy: 0.7147
# Epoch 11/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.5911 - accuracy: 0.7800 - val_loss: 0.5257 - val_accuracy: 0.8162
# Epoch 12/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.5093 - accuracy: 0.8271 - val_loss: 0.4383 - val_accuracy: 0.8665
# Epoch 13/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.4461 - accuracy: 0.8466 - val_loss: 0.8319 - val_accuracy: 0.6905
# Epoch 14/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.4078 - accuracy: 0.8635 - val_loss: 0.6142 - val_accuracy: 0.7969
# Epoch 15/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.3615 - accuracy: 0.8808 - val_loss: 0.2563 - val_accuracy: 0.9246
# Epoch 16/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.3197 - accuracy: 0.8915 - val_loss: 0.4441 - val_accuracy: 0.8375
# Epoch 17/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.2751 - accuracy: 0.9151 - val_loss: 0.2380 - val_accuracy: 0.9197
# Epoch 18/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.4664 - accuracy: 0.8690 - val_loss: 0.2789 - val_accuracy: 0.8994
# Epoch 19/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.2750 - accuracy: 0.9042 - val_loss: 0.2745 - val_accuracy: 0.9101
# Epoch 20/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.2394 - accuracy: 0.9272 - val_loss: 0.2306 - val_accuracy: 0.9275
# 17/17 [==============================] - 19s 1s/step - loss: 0.0163 - accuracy: 0.9945 - val_loss: 0.0721 - val_accuracy: 0.9826
# Epoch 85/100
# 17/17 [==============================] - 19s 1s/step - loss: 0.0167 - accuracy: 0.9959 - val_loss: 0.0745 - val_accuracy: 0.9874
# Epoch 86/100
# 17/17 [==============================] - 19s 1s/step - loss: 0.0224 - accuracy: 0.9923 - val_loss: 0.0652 - val_accuracy: 0.9845
# Epoch 87/100
# 17/17 [==============================] - 19s 1s/step - loss: 0.0051 - accuracy: 0.9986 - val_loss: 0.0813 - val_accuracy: 0.9826
# Epoch 88/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.0052 - accuracy: 0.9986 - val_loss: 0.0867 - val_accuracy: 0.9816
# Epoch 89/100
# 17/17 [==============================] - 19s 1s/step - loss: 0.0396 - accuracy: 0.9896 - val_loss: 0.0487 - val_accuracy: 0.9884
# Epoch 90/100
# 17/17 [==============================] - 19s 1s/step - loss: 0.0049 - accuracy: 0.9983 - val_loss: 0.0917 - val_accuracy: 0.9710
# Epoch 91/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.0103 - accuracy: 0.9969 - val_loss: 0.0670 - val_accuracy: 0.9865
# Epoch 92/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.0281 - accuracy: 0.9918 - val_loss: 0.0837 - val_accuracy: 0.9836
# Epoch 93/100
# 17/17 [==============================] - 19s 1s/step - loss: 0.0062 - accuracy: 0.9983 - val_loss: 0.0787 - val_accuracy: 0.9816
# Epoch 94/100
# 17/17 [==============================] - 19s 1s/step - loss: 0.0047 - accuracy: 0.9990 - val_loss: 0.1027 - val_accuracy: 0.9797
# Epoch 95/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.0120 - accuracy: 0.9969 - val_loss: 0.0778 - val_accuracy: 0.9836
# Epoch 96/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.0100 - accuracy: 0.9976 - val_loss: 0.1010 - val_accuracy: 0.9720
# Epoch 97/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.0136 - accuracy: 0.9947 - val_loss: 0.1195 - val_accuracy: 0.9729
# Epoch 98/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.0089 - accuracy: 0.9988 - val_loss: 0.0898 - val_accuracy: 0.9807
# Epoch 99/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.0311 - accuracy: 0.9942 - val_loss: 0.0793 - val_accuracy: 0.9787
# Epoch 100/100
# 17/17 [==============================] - 18s 1s/step - loss: 0.0065 - accuracy: 0.9983 - val_loss: 0.0584 - val_accuracy: 0.9884

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.figure("Model Metrics",(20,10))
plt.title('model accuracy')
plt.subplot(2,1,1)
plt.plot(history.history['accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')

plt.subplot(2,1,2)
plt.plot(history.history['val_accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.tight_layout()
plt.show()

# %%
plt.figure("Model Metrics",(20,10))
plt.title('model accuracy')
plt.subplot(2,1,1)
plt.plot(history.history['loss'])
plt.ylabel('loss')
plt.xlabel('epoch')

plt.subplot(2,1,2)
plt.plot(history.history['val_loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.tight_layout()
plt.show()

# %%
model.save('../model/saved/scratch_model.h5')
